# %% [markdown]
# # Assignment 4

# %% [markdown]
# ## Pandas and plotting exercises

# %% [markdown]
# Execute the following to import our libraries and our dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

anscombe_df = pd.read_csv('https://raw.githubusercontent.com/benjum/UCLA-23W-DH140/main/Weeks/Week04/data/anscombe.csv')
anscombe_df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %% [markdown]
# The variable `anscombe_df` now contains a dataframe of the data in Anscombe's quartet. You can read about that dataset [here](https://en.wikipedia.org/wiki/Anscombe%27s_quartet).

# %% [markdown]
# In class, we covered several useful methods for exploring dataframes.
#
# Execute a method that outputs the first five rows of the dataframe.

# %%
anscombe_df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %% [markdown]
# Output the last five rows of the dataframe.

# %%
anscombe_df.tail()
# Out:
#    dataset     x      y
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %% [markdown]
# Output the number of rows and columns of the dataframe.

# %%
anscombe_df.shape
# Out:
# (44, 3)

# %% [markdown]
# Output the column names of the dataframe.

# %%
anscombe_df.columns
# Out:
# Index(['dataset', 'x', 'y'], dtype='object')

# %% [markdown]
# Output the datatypes of each column.

# %%
anscombe_df.dtypes
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %% [markdown]
# Output summary statistics about the dataframe.

# %%
anscombe_df.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %%
# or...
anscombe_df.describe(include='all')
# Out:
#        dataset          x          y
# count       44  44.000000  44.000000
# unique       4        NaN        NaN
# top          I        NaN        NaN
# freq        11        NaN        NaN
# mean       NaN   9.000000   7.500682
# std        NaN   3.198837   1.958925
# min        NaN   4.000000   3.100000
# 25%        NaN   7.000000   6.117500
# 50%        NaN   8.000000   7.520000
# 75%        NaN  11.000000   8.747500
# max        NaN  19.000000  12.740000

# %% [markdown]
# Output the values that are in the `dataset` column.

# %%
anscombe_df['dataset']
# Out:
# 0       I
# 1       I
# 2       I
# 3       I
# 4       I
# 5       I
# 6       I
# 7       I
# 8       I
# 9       I
# 10      I
# 11     II
# 12     II
# 13     II
# 14     II
# 15     II
# 16     II
# 17     II
# 18     II
# 19     II
# 20     II
# 21     II
# 22    III
# 23    III
# 24    III
# 25    III
# 26    III
# 27    III
# 28    III
# 29    III
# 30    III
# 31    III
# 32    III
# 33     IV
# 34     IV
# 35     IV
# 36     IV
# 37     IV
# 38     IV
# 39     IV
# 40     IV
# 41     IV
# 42     IV
# 43     IV
# Name: dataset, dtype: object

# %% [markdown]
# Use `loc` to output the first 10 rows.

# %%
anscombe_df.loc[0:9]
# Out:
#   dataset     x      y
# 0       I  10.0   8.04
# 1       I   8.0   6.95
# 2       I  13.0   7.58
# 3       I   9.0   8.81
# 4       I  11.0   8.33
# 5       I  14.0   9.96
# 6       I   6.0   7.24
# 7       I   4.0   4.26
# 8       I  12.0  10.84
# 9       I   7.0   4.82

# %% [markdown]
# Use `loc` to output the values from the first 10 rows of the `'x'` column.

# %%
anscombe_df.loc[0:9, 'x']
# Out:
# 0    10.0
# 1     8.0
# 2    13.0
# 3     9.0
# 4    11.0
# 5    14.0
# 6     6.0
# 7     4.0
# 8    12.0
# 9     7.0
# Name: x, dtype: float64

# %% [markdown]
# Use `loc` to output the rows for which `dataset` is equal to `III`.

# %%
anscombe_df.loc[anscombe_df['dataset'] == 'III']
# Out:
#    dataset     x      y
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73

# %% [markdown]
# Make a line plot of y against x for dataset III.

# %%
anscombe_df.loc[anscombe_df['dataset'] == 'III'].plot(x='x', y='y')
# Out:
# <AxesSubplot: xlabel='x'>

# %% [markdown]
# Make a scatter plot of y against x for dataset III.

# %%
anscombe_df.loc[anscombe_df['dataset'] == 'III'].plot(x='x', y='y', kind='scatter')
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %% [markdown]
# Make scatter plots for the other 3 datasets.

# %%
anscombe_df.loc[anscombe_df['dataset'] == 'I'].plot(x='x', y='y', kind='scatter')
anscombe_df.loc[anscombe_df['dataset'] == 'II'].plot(x='x', y='y', kind='scatter')
anscombe_df.loc[anscombe_df['dataset'] == 'IV'].plot(x='x', y='y', kind='scatter')
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %% [markdown]
# All of the datasets in Anscombe's quartet have the same linear regression line, $y = 3.0 + 0.5x$
#
# We can plot that line by executing the following:

# %%
# generates 10 points from 3 to 14 and assigns the array to x
x = np.linspace(3,14,10)

# generates 10 points that satisfy (3 + 0.5*x) and assigns the array to y
y = 3 + 0.5*x

# makes a scatter plot with the x and y values
plt.scatter(x,y)

# adds a line plot to our scatter plot
plt.plot(x,y)

# shows the completed figure
plt.show()

# %% [markdown]
# Now make a figure that includes both:
# * a scatter plot of dataset I from `anscombe_df`
# * the line plot of the linear regression line (and only the line)
#
# Note: place the line(s) of code relevant to the scatter plot before the line(s) of code relevant to the line plot

# %%
anscombe_df.loc[anscombe_df['dataset'] == 'I'].plot(x='x', y='y', kind='scatter')
plt.plot(x,y)
plt.show()

# %% [markdown]
# Make the same plot again with:
#
# * an appropriate title
# * 16-pt font size for the axis labels and title
# * make the line blue
# * make the scatter points black

# %%
anscombe_df.loc[anscombe_df['dataset'] == 'I'].plot(x='x', y='y', kind='scatter', color='black')
plt.plot(x, y, color='blue')
plt.title("Anscombe's Dataset I",fontsize=16)
plt.xlabel('x',fontsize=16)
plt.ylabel('y',fontsize=16)
plt.show()

# %% [markdown]
# # Free form section

# %% [markdown]
# In this week's class, we looked at two datasets from the CORGIS website.
#
# For this section of the assignment, choose another CORGIS dataset and get the link to the downloadable CSV file for that dataset.
# * For example, in the Music example, we would:
#   1. go to https://corgis-edu.github.io/corgis/csv/
#   2. scroll down to "Music" and follow the link to the "Music" data page
#   3. go to the "Download" header
#   4. right-click on the downloadable file link and select "Copy link address"
#     * for Music, the link we would copy is https://corgis-edu.github.io/corgis/datasets/csv/music/music.csv
#   5. we could then import the data using `pd.read_csv('https://corgis-edu.github.io/corgis/datasets/csv/music/music.csv')`

# %% [markdown]
# Use Pandas' `read_csv()` function to import your new CORGIS dataset into a dataframe variable.

# %%
# THIS SOLUTION SHOWS MUSIC, BUT THE SOLUTION HERE IS VERY FLEXIBLE
df = pd.read_csv('https://corgis-edu.github.io/corgis/datasets/csv/music/music.csv')

# %% [markdown]
# Look at summary information about the dataframe, the column names, and sample rows.
# * You can add as many cells as you want for exploration.

# %%
df.describe()
# Out:
#        artist.familiarity  artist.hotttnesss  artist.latitude  \
# count        10000.000000       10000.000000     10000.000000
# mean             0.565230           0.385552        13.904283
# std              0.160528           0.143647        20.356379
# min              0.000000           0.000000       -41.280540
# 25%              0.467570           0.325266         0.000000
# 50%              0.563584           0.380742         0.000000
# 75%              0.668020           0.453858        34.419250
# max              1.000000           1.082503        69.651020
#
#        artist.location  artist.longitude  artist.similar  artist.terms_freq  \
# count        10000.000      10000.000000         10000.0       1.000000e+04
# mean             0.078        -23.923863             0.0       2.248903e+02
# std              7.800         43.723359             0.0       2.239216e+04
# min              0.000       -162.436500             0.0       0.000000e+00
# 25%              0.000        -73.948880             0.0       9.476125e-01
# 50%              0.000          0.000000             0.0       9.999728e-01
# 75%              0.000          0.000000             0.0       1.000000e+00
# max            780.000        174.767140             0.0       2.239217e+06
#
#           release.id  release.name  song.artist_mbtags  ...     song.mode  \
# count   10000.000000  10000.000000        10000.000000  ...  10000.000000
# mean   371024.058400     23.096000            0.000033  ...      0.691000
# std    236777.828209   1322.901526            0.003330  ...      0.462104
# min         0.000000      0.000000            0.000000  ...      0.000000
# 25%    172858.000000      0.000000            0.000000  ...      0.000000
# 50%    333103.000000      0.000000            0.000000  ...      1.000000
# 75%    573532.500000      0.000000            0.000000  ...      1.000000
# max    823599.000000  85555.000000            0.333000  ...      1.000000
#
#        song.mode_confidence  song.start_of_fade_out  song.tatums_confidence  \
# count          10000.000000            10000.000000            10000.000000
# mean               0.477765              229.883436                0.507875
# std                0.191269              112.024303                0.332357
# min                0.000000              -21.394000                0.000000
# 25%                0.360000              168.855750                0.237000
# 50%                0.487000              213.864500                0.500000
# 75%                0.606000              266.274750                0.774250
# max                1.000000             1813.426000                9.227560
#
#        song.tatums_start    song.tempo  song.time_signature  \
# count       10000.000000  10000.000000         10000.000000
# mean            0.299886    122.900913             3.564443
# std             0.510925     35.204746             1.266620
# min             0.000000      0.000000             0.000000
# 25%             0.110692     96.959500             3.000000
# 50%             0.191520    120.156500             4.000000
# 75%             0.294743    144.006750             4.000000
# max            12.245830    262.828000             7.000000
#
#        song.time_signature_confidence    song.title     song.year
# count                    10000.000000  10000.000000  10000.000000
# mean                         0.599785     10.011400    934.704600
# std                          8.991567    945.486852    996.650657
# min                          0.000000      0.000000      0.000000
# 25%                          0.097750      0.000000      0.000000
# 50%                          0.551000      0.000000      0.000000
# 75%                          0.864000      0.000000   2000.000000
# max                        898.891000  94496.000000   2010.000000
#
# [8 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['artist.familiarity', 'artist.hotttnesss', 'artist.id',
#        'artist.latitude', 'artist.location', 'artist.longitude', 'artist.name',
#        'artist.similar', 'artist.terms', 'artist.terms_freq', 'release.id',
#        'release.name', 'song.artist_mbtags', 'song.artist_mbtags_count',
#        'song.bars_confidence', 'song.bars_start', 'song.beats_confidence',
#        'song.beats_start', 'song.duration', 'song.end_of_fade_in',
#        'song.hotttnesss', 'song.id', 'song.key', 'song.key_confidence',
#        'song.loudness', 'song.mode', 'song.mode_confidence',
#        'song.start_of_fade_out', 'song.tatums_confidence', 'song.tatums_start',
#        'song.tempo', 'song.time_signature', 'song.time_signature_confidence',
#        'song.title', 'song.year'],
#       dtype='object')

# %%
df.sample(3)
# Out:
#       artist.familiarity  artist.hotttnesss           artist.id  \
# 5359            0.564594           0.310069  ARO3PIY1187B989933
# 6065            0.594867           0.382847  ARE36MM1187B991E50
# 3222            0.501801           0.291450  ARDMKKB1187B9A0EDA
#
#       artist.latitude  artist.location  artist.longitude  \
# 5359           0.0000                0           0.00000
# 6065          31.1689                0        -100.07715
# 3222          31.1689                0        -100.07715
#
#                 artist.name  artist.similar       artist.terms  \
# 5359                 Virtue             0.0  progressive house
# 6065  Blind Lemon Jefferson             0.0      country blues
# 3222                  TrA"s             0.0         latin jazz
#
#       artist.terms_freq  ...  song.mode  song.mode_confidence  \
# 5359            1.00000  ...          1                 0.308
# 6065            0.95035  ...          0                 0.263
# 3222            1.00000  ...          0                 0.494
#
#       song.start_of_fade_out  song.tatums_confidence  song.tatums_start  \
# 5359                 208.863                   1.000            0.14536
# 6065                 181.226                   0.295            0.09874
# 3222                 412.177                   1.000            0.23095
#
#       song.tempo  song.time_signature  song.time_signature_confidence  \
# 5359     165.152                  4.0                           0.403
# 6065     162.496                  4.0                           0.321
# 3222     125.983                  4.0                           0.000
#
#       song.title  song.year
# 5359           0          0
# 6065           0       1927
# 3222           0          0
#
# [3 rows x 35 columns]

# %% [markdown]
# Make several visualizations of the data contained in this dataset.
# * You should make at least three different kinds of plots (bar, line, scatter, horizontal bar, histogram, ...).
# * In at least one plot, you should plot data from a subset of rows rather than from the entire column of values.
# * All plots should present a visualization that is reasonably understandable (no zigzagging lines in a chaotic mess, there should not be a large number of overlapping labels, and etc)
# * You can add extra cells as needed.

# %%
df.loc[df['artist.name']=='Gwen Stefani'].plot(x='artist.familiarity', 
                                               y='song.hotttnesss', 
                                               kind='scatter')
plt.title('Song Hotttnesss vs Artist Familiarity for Gwen Stefani')
plt.show()

# %%
df['song.hotttnesss'].plot(x='song.hotttnesss',kind='hist')
plt.title('Histogram of Song Hotttnesss for all artists')
plt.xlabel('Song Hotttnesss')
plt.show()

# %%
top20 = df.groupby('artist.name')['song.hotttnesss'].mean().sort_values(ascending=False)[:20]
top20[::-1].plot(x='artist.name',y='song.hotttnesss',kind='barh')
plt.xlabel('Average Song Hotttnesss Metric')
plt.ylabel('Artist Name')
plt.show()

# %% [markdown]
# # Submit
# Submit this assignment by:
#
# * Saving your work
# * Clicking on the Submit button at the top
